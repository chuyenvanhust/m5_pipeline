# %%
import pandas as pd


df_schema = pd.read_parquet("../data/processed/sales_clean.parquet", engine='pyarrow').head(0)
print(df_schema.info())


print(df_schema.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          0 non-null      datetime64[ns]
#  1   item_id       0 non-null      object
#  2   store_id      0 non-null      object
#  3   state_id      0 non-null      object
#  4   sales         0 non-null      float64
#  5   sell_price    0 non-null      float64
#  6   wm_yr_wk      0 non-null      int64
#  7   weekday       0 non-null      object
#  8   month         0 non-null      int64
#  9   event_name_1  0 non-null      object
#  10  snap_CA       0 non-null      int64
#  11  snap_TX       0 non-null      int64
#  12  snap_WI       0 non-null      int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(5)
# memory usage: 132.0+ bytes
# None
# date            datetime64[ns]
# item_id                 object
# store_id                object
# state_id                object
# sales                  float64
# sell_price             float64
# wm_yr_wk                 int64
# weekday                 object
# month                    int64
# event_name_1            object
# snap_CA                  int64
# snap_TX                  int64
# snap_WI                  int64
# dtype: object

# %%
df_preview = pd.read_parquet("../data/processed/sales_clean.parquet", engine='pyarrow').head(10)
print(df_preview)
# Out:
#         date      item_id store_id state_id  sales  sell_price  wm_yr_wk  \
# 0 2011-01-29  FOODS_1_001     CA_1       CA    3.0         2.0     11101
# 1 2011-01-30  FOODS_1_001     CA_1       CA    0.0         2.0     11101
# 2 2011-01-31  FOODS_1_001     CA_1       CA    0.0         2.0     11101
# 3 2011-02-01  FOODS_1_001     CA_1       CA    1.0         2.0     11101
# 4 2011-02-02  FOODS_1_001     CA_1       CA    3.5         2.0     11101
# 5 2011-02-03  FOODS_1_001     CA_1       CA    2.0         2.0     11101
# 6 2011-02-04  FOODS_1_001     CA_1       CA    0.0         2.0     11101
# 7 2011-02-05  FOODS_1_001     CA_1       CA    2.0         2.0     11102
# 8 2011-02-06  FOODS_1_001     CA_1       CA    0.0         2.0     11102
# 9 2011-02-07  FOODS_1_001     CA_1       CA    0.0         2.0     11102
#
#      weekday  month event_name_1  snap_CA  snap_TX  snap_WI
# 0   Saturday      1         None        0        0        0
# 1     Sunday      1         None        0        0        0
# 2     Monday      1         None        0        0        0
# 3    Tuesday      2         None        1        1        0
# 4  Wednesday      2         None        1        0        1
# 5   Thursday      2         None        1        1        1
# 6     Friday      2         None        1        0        0
# 7   Saturday      2         None        1        1        1
# 8     Sunday      2    SuperBowl        1        1        1
# 9     Monday      2         None        1        1        0
