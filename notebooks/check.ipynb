# %%
import pandas as pd


df_schema = pd.read_parquet("../data/processed/sales_clean.parquet", engine='pyarrow').head(0)
print(df_schema.info())


print(df_schema.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         0 non-null      datetime64[ns]
#  1   item_id      0 non-null      object
#  2   store_id     0 non-null      object
#  3   sales        0 non-null      float32
#  4   day_of_week  0 non-null      int8
#  5   month        0 non-null      int8
#  6   is_holiday   0 non-null      int32
#  7   is_weekend   0 non-null      int32
#  8   snap         0 non-null      int32
#  9   sell_price   0 non-null      float32
#  10  rolling_7    0 non-null      float64
#  11  rolling_28   0 non-null      float64
#  12  lag_7        0 non-null      float32
#  13  lag_14       0 non-null      float32
#  14  lag_28       0 non-null      float32
# dtypes: datetime64[ns](1), float32(5), float64(2), int32(3), int8(2), object(2)
# memory usage: 132.0+ bytes
# None
# date           datetime64[ns]
# ...

# %%
df_preview = pd.read_parquet("../data/processed/sales_clean.parquet", engine='pyarrow').head(10)
print(df_preview)
# Out:
#         date      item_id store_id  sales  day_of_week  month  is_holiday  \
# 0 2011-01-29  FOODS_1_001     CA_1    3.0            5      1           0
# 1 2011-01-30  FOODS_1_001     CA_1    0.0            6      1           0
# 2 2011-01-31  FOODS_1_001     CA_1    0.0            0      1           0
# 3 2011-02-01  FOODS_1_001     CA_1    1.0            1      2           0
# 4 2011-02-02  FOODS_1_001     CA_1    4.0            2      2           0
# 5 2011-02-03  FOODS_1_001     CA_1    2.0            3      2           0
# 6 2011-02-04  FOODS_1_001     CA_1    0.0            4      2           0
# 7 2011-02-05  FOODS_1_001     CA_1    2.0            5      2           0
# 8 2011-02-06  FOODS_1_001     CA_1    0.0            6      2           1
# 9 2011-02-07  FOODS_1_001     CA_1    0.0            0      2           0
#
#    is_weekend  snap  sell_price  rolling_7  rolling_28  lag_7  lag_14  lag_28
# ...

# %%
df_analysis = pd.read_csv("../data/processed/analysis_profile.csv", engine='pyarrow')
print (df_analysis.info() )
print (df_analysis.head(20) )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item_id        30490 non-null  object
#  1   store_id       30490 non-null  object
#  2   mean_sales     30490 non-null  float64
#  3   std_sales      30490 non-null  float64
#  4   cv             30490 non-null  float64
#  5   zero_ratio     30490 non-null  float64
#  6   missing_ratio  30490 non-null  float64
#  7   trend_slope    30490 non-null  float64
#  8   total_days     30490 non-null  int64
#  9   demand_type    30490 non-null  object
#  10  profile_scope  30490 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 2.6+ MB
# None
#         item_id store_id  mean_sales  std_sales        cv  zero_ratio  \
# 0   FOODS_1_001     CA_1    0.742916   1.050948  1.414626    0.564142
# 1   FOODS_1_001     CA_2    1.090160   1.477184  1.355016    0.484802
# ...

# %%
df_sampling = pd.read_csv("../data/processed/sampling_profile.csv", engine='pyarrow')
print (df_sampling.info() )
print (df_sampling.head(20) )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item_id        30490 non-null  object
#  1   store_id       30490 non-null  object
#  2   mean_sales     30490 non-null  float64
#  3   std_sales      30490 non-null  float64
#  4   cv             30474 non-null  float64
#  5   zero_ratio     30490 non-null  float64
#  6   missing_ratio  30490 non-null  float64
#  7   trend_slope    30490 non-null  float64
#  8   total_days     30490 non-null  int64
#  9   demand_type    30490 non-null  object
#  10  profile_scope  30490 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 2.6+ MB
# None
#         item_id store_id  mean_sales  std_sales        cv  zero_ratio  \
# 0   FOODS_1_001     CA_1    0.734661   1.047136  1.425332    0.568353
# 1   FOODS_1_001     CA_2    1.101722   1.482581  1.345694    0.480624
# ...
